# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo-2/blob/main/assignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Equipo 2 - Integrantes:**
# * Andrea Carolina Treviño Garza A01034993
# * Mario Alberto Corona Cadenas A01793016

# %% [markdown]
# ## **ACTIVIDAD 2 DEL PROYECTO FINAL**

# %% [markdown]
# Identificar una metodología que vas a usar durante la realización del proyecto:
# * CRISP - DM (Cross Industry Standard Process for Data Mining)

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# Fases de metodología:
# 1. Entender problema
# 2. Entender los datos
# 3. Preparar los datos
# 4. Modelar
# 5. Evalucación
# 6. Implementación

# %% [markdown]
# #**1.   Entender el problema:**
# *   Determinar los objetivos generales de la aplicación para categotizar canciones.
# *   Definir indicadores claves de éxito para proyecto.

# %% [markdown]
# #**2.   Entender los datos:**
# *   Definir fuente de datos (Music Dataset)
# *   Documentar problemas/requisitos para preparación de datos.
# *   Realizar estadísticas básicas.

# %% [markdown]
# #**3.   Preparar los datos:**
# *   Integrar y seleccionar datos.
# *   Transformar y limpiar datos.
# *   Datos listos para empezar a modelar.

# %% [markdown]
# #**4.   Modelar:**
# *   Seleccionar técnica de modelado que corresponda.
# *   Desarrollar método de pruebas.
# *   Construcción de modelo eligiendo configuración inicial de parámetros y evaluarlo.

# %% [markdown]
# #**5.   Evaluación:**
# *   Evaluación consultando información similar en internet.
# *   Revisión de indicadors clave.
# *   Definir próximos pasos.

# %% [markdown]
# #**6.   Implementación:**
# *   Seguimiento y evaluación de eficacia.
# *   Generación de un reporte final de resultados.

# %% [markdown]
# ##**Bibliografía:**
# *   Sridharan, M. (2022, 6 julio). CRISP-DM - A Framework For Data Mining & Analysis. Think Insights. Recuperado 25 de septiembre de 2022, de https://thinkinsights.net/data-literacy/crisp-dm/
# *   Hotz, B. N. (2022, 8 agosto). What is CRISP DM? Data Science Process Alliance. Recuperado 25 de septiembre de 2022, de https://www.datascience-pm.com/crisp-dm-2/
